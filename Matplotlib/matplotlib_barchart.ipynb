# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Write a Python programming to display a bar chart of the popularity of programming
# Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming Languages.

'''


def barchart_popularity(languages,popularity):

    """
    Description:
        Function will isplay a bar chart of the popularity of programming Languages.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    plt.bar(languages, popularity, color='skyblue')

    plt.title('Popularity of Programming Languages')
    plt.xlabel('Programming Languages')
    plt.ylabel('Popularity (%)')

    plt.show()



def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 2. Write a Python programming to display a horizontal bar chart of the popularity of
# programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a horizontal bar chart of the popularity of programming Languages

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    plt.barh(languages, popularity, color='skyblue')

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')

    plt.show()



def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 3. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use uniform color.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Use uniform color.

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal give uniform for each bar.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    plt.barh(languages, popularity, color='skyblue')

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')

    plt.show()



def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 4. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use different color for each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Use different color for each bar.

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and will give different color for each bar.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    plt.barh(languages, popularity, color=['skyblue','green','red','cyan','hotpink','yellow'])

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')

    plt.show()



def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 5. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Attach a text label above each bar displaying its popularity (float value).
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Attach a text label above each bar displaying its popularity (float value).

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and will give different color for each bar.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    plt.barh(languages, popularity, color=['skyblue','green','red','cyan','hotpink','yellow'])

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')
    for cordinates in range(len(popularity)):
        plt.text(popularity[cordinates],cordinates,popularity[cordinates])
    plt.show()



def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 6. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Make blue border to each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Make blue border to each bar.

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and will make blue border to each bar.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    plt.barh(languages, popularity, color=['skyblue','green','red','cyan','hotpink','yellow'],edgecolor='blue')

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')

    plt.show()


def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 7. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Specify the position of each bar plot.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Specify the position of each bar plot.

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and will specify the position of each bar plot.

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    start_positions = np.array([5, 10, 15, 20, 25, 30])

    plt.barh(languages, popularity, color=['skyblue','green','red','cyan','hotpink','yellow'],edgecolor='blue',left=start_positions)

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')

    plt.show()


def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 8. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Select the width of each bar and their positions.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Select the width of each bar and their positions.

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and will select the width of each bar and their positions

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    start_positions = np.arange(len(languages))*2

    plt.barh(languages, popularity,height=0.5, color=['skyblue','green','red','cyan','hotpink','yellow'],edgecolor='blue',left=start_positions)

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')

    plt.show()


def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 9. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Increase bottom margin.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python programming to display a bar chart of the popularity of programming
        Languages. Increase bottom margin.

'''


def horizontal_barchart_popularity(languages,popularity):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and increase bottom margin

    Parameter:
        languages:list of languages
        popularity:list of popularity of language respectfully
      
    Return:
        None    
    """

    plt.figure(figsize=(10, 6))
    start_positions = np.arange(len(languages))*2

    plt.barh(languages, popularity,height=0.5,color=['skyblue','green','red','cyan','hotpink','yellow'],edgecolor='blue',left=start_positions)

    plt.title('Popularity of Programming Languages')
    plt.ylabel('Programming Languages')
    plt.xlabel('Popularity (%)')
    plt.subplots_adjust(bottom=0.4)

    plt.show()


def main():
    try:
        languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
        popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]
        horizontal_barchart_popularity(languages,popularity)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 10. Write a Python program to create bar plot of scores by group and gender. Use multiple X
# values on the same chart for men and women.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to create bar plot of scores by group and gender. Use multiple X
        values on the same chart for men and women.

'''


def horizontal_gender_barchart(means_men,means_women):

    """
    Description:
        Function will display a bar chart of the popularity of programming Languages in horizontal and increase bottom margin

    Parameter:
        means_men:mens score in list
        means_women:women scores in list
      
    Return:
        None    
    """

    groups = ['Group1', 'Group2', 'Group3', 'Group4', 'Group5']

    n_groups = len(groups)

    index = np.arange(n_groups)

    bar_width = 0.35

    plt.bar(index, means_men, bar_width, color='blue', label='Men')

    plt.bar(index + bar_width, means_women, bar_width, color='pink', label='Women')

    plt.xlabel('Groups')
    plt.ylabel('Scores')
    plt.title('Scores by group and gender')
    plt.xticks(index + bar_width / 2, groups) 
    plt.legend()

    plt.show()


def main():
    try:
        means_men = [22, 30, 35, 35, 26]
        means_women = [25, 32, 30, 35, 29]
        horizontal_gender_barchart(means_men,means_women)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 11. Write a Python program to create bar plot from a DataFrame.
# Sample Data Frame:
# a b c d e f
# 2,4,8,5,7,6
# 4,2,3,4,2,6
# 6,4,7,4,7,8
# 8,2,6,4,8,6
# 10,2,4,3,3,2

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to create bar plot from a DataFrame.

'''


def horizontal_dataframe_barchart(dataframe):

    """
    Description:
        Function will create bar plot from a DataFrame

    Parameter:
        dataframe:will plot the bar chart for dataframe
      
    Return:
        None    
    """

    dataframe.plot(kind='bar')

    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.title('Bar Plot from DataFrame')
    plt.xticks(rotation=0)
    plt.show()


def main():
    try:
        dataframe=pd.read_csv('fdataframe.csv')
        horizontal_dataframe_barchart(dataframe)

    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 12. Write a Python program to create bar plots with error bars on the same figure. Sample Date
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to create bar plots with error bars on the same figure

'''


def error_barchart(mean_velocity,std_deviation):

    """
    Description:
        Function will create bar plot with error bars on same figure

    Parameter:
        mean_velocity:means value
        std_deviation:standard deviation value
      
    Return:
        None    
    """

    categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4']

    x = np.arange(len(categories))

    bar_width = 0.5

    plt.bar(x, mean_velocity, bar_width, yerr=std_deviation, color='skyblue', edgecolor='black', label='Mean Velocity')

    plt.xlabel('Categories')
    plt.ylabel('Mean Velocity')
    plt.title('Bar Plot with Error Bars')
    plt.xticks(x, categories) 
    plt.legend()

    plt.show()


def main():
    try:
        mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
        std_deviation = [0.3314, 0.2278, 0.2836, 0.2645]
        error_barchart(mean_velocity,std_deviation)

    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 13. Write a Python program to create bar plots with errorbars on the same figure. Attach a text
# label above each bar displaying men means (integer value).
# Sample Data
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to create bar plots with errorbars on the same figure. Attach a text
        label above each bar displaying men means (integer value).

'''


def error_barchart(mean_velocity,std_deviation):

    """
    Description:
        Function will create bar plot with error bars on same figure  will  add text label

    Parameter:
        mean_velocity:means value
        std_deviation:standard deviation value
      
    Return:
        None    
    """

    categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4']
    mean_velocity_int = [int(round(value  * 1000)) for value in mean_velocity]

    x = np.arange(len(categories))

    bar_width = 0.5

    plt.figure(figsize=(10, 6))
    bars = plt.bar(x, mean_velocity, bar_width, yerr=std_deviation, capsize=5, color='skyblue', edgecolor='black', label='Mean Velocity')

    plt.xlabel('Categories')
    plt.ylabel('Mean Velocity')
    plt.title('Bar Plot with Error Bars and Text Labels')
    plt.xticks(x, categories)  
    plt.legend()


    for bar, mean in zip(bars, mean_velocity_int):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{mean}', ha='center', va='bottom')

    plt.show()


def main():
    try:
        mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
        std_deviation = [0.3314, 0.2278, 0.2836, 0.2645]
        error_barchart(mean_velocity,std_deviation)

    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to draw a line with suitable label in the x axis, y axis and a title

'''

def draw_line(xpoints,ypoints):

    """
    Description:
        function will plot the straight line graph using matplotlib plot 

    Parameter:
        array1,array2:will use this this array as coordinates to plot graph

    Return:
        None    
    """
    plt.plot(xpoints,ypoints,color="red")
    plt.xlabel("x axis")
    plt.ylabel("y axis")
    plt.title("Straight line Graph")
    plt.show()
   

def main():
    try:
        array1=np.arange(101)
        array2=np.arange(101)

        draw_line(array1,array2)

    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis
# , y axis and a title

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to draw a line using given axis values with suitable label in the x axis, y axis and a title

'''

def draw_line(xpoints,ypoints):

    """
    Description:
        function will plot the straight line graph using matplotlib plot 

    Parameter:
        array1,array2:will use this this array as coordinates to plot graph

    Return:
        None    
    """
    plt.plot(xpoints,ypoints,color="red")
    plt.xlabel("x axis")
    plt.ylabel("y axis")
    plt.title("Straight line Graph")
    plt.show()
   

def main():
    try:
        array1=np.arange(101)
        array2=np.arange(101)

        draw_line(array1,array2)

    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to draw a line using given axis values taken from a text file, with
        suitable label in the x axis, y axis and a title

'''

def draw_line(xpoints,ypoints):

    """
    Description:
        function will plot the straight line graph using matplotlib plot 

    Parameter:
        array1,array2:will use this this array as coordinates to plot graph

    Return:
        None    
    """
    plt.plot(xpoints,ypoints,color="red")
    plt.xlabel("x axis")
    plt.ylabel("y axis")
    plt.title("Graph",loc="center")
    plt.show()
   

def main():
    try:
        array1=[]
        array2=[]

        with open('test.txt','r') as file:
            
            for line in file:
                values=line.split()
                if  len(values)==2:
                    if values[0].isdigit() and values[1].isdigit():
                        array1.append((int)(values[0]))
                        array2.append((int)(values[1]))

        draw_line(np.array(array1),np.array(array2))

    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 03-10-16,774.25,776.065002,769.5,772.559998
# 04-10-16,776.030029,778.710022,772.890015,776.429993
# 05-10-16,779.309998,782.070007,775.650024,776.469971
# 06-10-16,779,780.47998,775.539978,776.859985
# 07-10-16,779.659973,779.659973,770.75,775.080017

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to draw line charts of the financial data of Alphabet Inc. between
        October 3, 2016 to October 7, 2016

'''


def extract_csv(start_date,end_date):

    """
    Description:
        function will plot charts of the financial data of Alphabet Inc. between
        October 3, 2016 to October 7, 2016 

    Parameter:
       start_date:will use this this array as coordinates to plot graph
       end_date:

    Return:
        None    
    """

    data_frame=pd.read_csv("fdata.csv",parse_dates=['Date'])
    data_frame_filtered = data_frame[(data_frame['Date'] >= start_date) & (data_frame['Date'] <= end_date)]

    data_frame.plot(x='Date', y=['Open', 'High', 'Low', 'Close'], marker='o')

    plt.xlabel('Date')

    plt.ylabel('Price (USD)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    plt.title('Alphabet Inc. Financial Data (Oct 3, 2016 - Oct 7, 2016)')
    plt.show()



def main():
    try:
        start_date ='2016-10-03'
        end_date ='2016-10-07'

        extract_csv(start_date,end_date)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each
# line.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to plot two or more lines on same plot with suitable legends of each line.

'''


def plot_two_line(ypoints1,ypoints2):

    """
    Description:
        Function will plot two or more lines on same plot 

    Parameter:
       ypoints1:y axis points in array1
       ypoints2:y axis points in array2

    Return:
        None    
    """
    
    plt.plot(ypoints1,color='hotpink',ls=':',label="first plot")
    plt.plot(ypoints2,color='red',ls='--',label="second plot")
    plt.xlabel("X axis")
    plt.ylabel("Y axis")
    plt.title("Graph with two or more plot")
    plt.legend()
    plt.show()


def main():
    try:
        ypoints1=np.random.randint(0,8,size=8)
        ypoints2=np.random.randint(0,8,size=8)
        
        plot_two_line(ypoints1,ypoints2)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to plot two or more lines with legends, different widths and colors.

'''


def plot_two_line(ypoints1,ypoints2):

    """
    Description:
        Function will plot two or more lines on same plot with different width and colors

    Parameter:
       ypoints1:y axis points in array1
       ypoints2:y axis points in array2

    Return:
        None    
    """
    
    plt.plot(ypoints1,color='hotpink',linewidth="10",label="first plot")
    plt.plot(ypoints2,color='red',linewidth="12.5",label="second plot")
    plt.xlabel("X axis")
    plt.ylabel("Y axis")
    plt.title("Graph with two or more plot")
    plt.legend()
    plt.show()


def main():
    try:
        ypoints1=np.random.randint(0,8,size=8)
        ypoints2=np.random.randint(0,8,size=8)
        
        plot_two_line(ypoints1,ypoints2)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to plot two or more lines with different styles

'''


def plot_two_line(ypoints1,ypoints2):

    """
    Description:
        Function will plot two or more lines on same plot with different style

    Parameter:
       ypoints1:y axis points in array1
       ypoints2:y axis points in array2

    Return:
        None    
    """
    
    plt.plot(ypoints1,color='hotpink',ls=':',label="first plot")
    plt.plot(ypoints2,color='red',ls='--',label="second plot")
    plt.xlabel("X axis")
    plt.ylabel("Y axis")
    plt.title("Line with differnt style")
    plt.legend()
    plt.show()


def main():
    try:
        ypoints1=np.random.randint(0,8,size=8)
        ypoints2=np.random.randint(0,8,size=8)
        
        plot_two_line(ypoints1,ypoints2)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 8. Write a Python program to plot two or more lines and set the line markers.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to plot two or more lines and set the line markers.

'''


def plot_two_line(ypoints1,ypoints2):

    """
    Description:
        Function will plot two or more lines and set the line markers.

    Parameter:
       ypoints1:y axis points in array1
       ypoints2:y axis points in array2

    Return:
        None    
    """
    
    plt.plot(ypoints1,color='hotpink',ls=':',marker='o',label="first plot")
    plt.plot(ypoints2,color='red',ls='--',marker='o',label="second plot")
    plt.xlabel("X axis")
    plt.ylabel("Y axis")
    plt.title("Lines with marker")
    plt.legend()
    plt.show()


def main():
    try:
        ypoints1=np.random.randint(0,8,size=8)
        ypoints2=np.random.randint(0,8,size=8)
        
        plot_two_line(ypoints1,ypoints2)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to display the current axis limits values and set new axis values.

'''


def plot_line(ypoints):

    """
    Description:
        Function will display the current axis limits values and set new axis values.

    Parameter:
       ypoints:y axis points in an array
      
    Return:
        None    
    """
    
    plt.plot(ypoints,color='hotpink',ls=':',marker='o')

    current_x_limits = plt.xlim() 
    current_y_limits = plt.ylim()  

    print("Current x-axis limits:", current_x_limits)
    print("Current y-axis limits:", current_y_limits)
    
    plt.xlabel("X axis")
    plt.ylabel("Y axis")
    plt.title("Line Plot with Custom Axis Limits")
    plt.xlim(2, 20) 
    plt.ylim(2, 20) 

    new_x_limits = plt.xlim()  
    new_y_limits = plt.ylim()  

    print("New x-axis limits:", new_x_limits)
    print("New y-axis limits:", new_y_limits)

    plt.show()


def main():
    try:
        ypoints=np.random.randint(0,8,size=8)

        plot_line(ypoints)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()
# Out:
# Current x-axis limits: (-0.35000000000000003, 7.35)
# Current y-axis limits: (0.7, 7.3)
# New x-axis limits: (2.0, 20.0)
# New y-axis limits: (2.0, 20.0)

# %% [markdown]
# 10. Write a Python program to plot quantities which have an x and y position.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to plot quantities which have an x and y position.

'''


def plot_line(ypoints):

    """
    Description:
        Function will plot quantities which have an x and y position.

    Parameter:
       ypoints:y axis points in an array
      
    Return:
        None    
    """
    xpoints=np.arange(0,8)
    plt.scatter(xpoints,ypoints, color='blue', label='Data Points')

    plt.plot(xpoints,ypoints, color='green', linestyle='-', label='Line Connection')


    plt.xlabel('X Position')
    plt.ylabel('Y Position')
    plt.title('Plot of Quantities with X and Y Positions')

    plt.show()


def main():
    try:
        ypoints=np.random.randint(0,8,size=8)

        plot_line(ypoints)


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command
# using arrays.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to plot several lines with different format styles in one command
        using arrays.

'''


def plot_multiple_line():

    """
    Description:
        Function will plot several lines with different format styles in one command
        using arrays.

    Parameter:
        None
      
    Return:
        None    
    """
    xpoint = np.linspace(0, 10, 100) 

    ypoint1 = np.sin(xpoint)        
    ypoint2 = np.cos(xpoint)          
    ypoint3 = np.tan(xpoint)          

    plt.plot(xpoint, ypoint1, 'r--', xpoint, ypoint2, 'g-.', xpoint, ypoint3, 'b:')

    plt.xlabel('X Axis')
    plt.ylabel('Y Axis')
    plt.title('Multiple Lines with Different Format Styles')

    plt.legend(['Sine', 'Cosine', 'Tangent'])

    plt.show()


def main():
    try:
        plot_multiple_line()


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 12. Write a Python program to create multiple types of charts

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title : Python program to create multiple types of charts.

'''


def plot_multiple_type_chart():

    """
    Description:
        Function will create multiple types of charts.
        using arrays.

    Parameter:
        None
      
    Return:
        None    
    """
    xpoints = np.linspace(0, 10, 100)
    ypoints1 = np.sin(xpoints)
    ypoints2 = np.cos(xpoints)
    categories = ['A', 'B', 'C', 'D', 'E']
    values = [10, 20, 15, 25, 30]
    sizes = [15, 30, 45, 10,20]


    # Create a figure and subplots
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))

    # Line Chart
    axs[0].plot(xpoints, ypoints1, 'r--', label='Sine')
    axs[0].plot(xpoints, ypoints2, 'b-.', label='Cosine')
    axs[0].set_title('Line Chart')
    axs[0].set_title('Line Chart')
    axs[0].set_xlabel('X Axis')
    axs[0].set_ylabel('Y Axis')
    axs[0].legend()

    # Bar Chart
    axs[1].bar(categories, values, color='green')
    axs[1].set_title('Bar Chart')
    axs[1].set_title('Bar Chart')
    axs[1].set_xlabel('Categories')
    axs[1].set_ylabel('Values')

    # Pie Chart
    axs[2].pie(sizes, labels=categories, autopct='%1.1f%%', startangle=140)
    axs[2].set_title('Pie Chart')

    # Adjust layout
    plt.tight_layout()
    plt.show()


def main():
    try:
        plot_multiple_type_chart()


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 13. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# linestyle -, width .5. and color blue.
# Date,Close
# 03-10-16,772.559998
# 04-10-16,776.429993
# 05-10-16,776.469971
# 06-10-16,776.859985
# 07-10-16,775.080017

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to display the grid and draw line charts of the closing value of
        Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
        linestyle -, width .5. and color blue.

'''


def plot_chart_with_grid():

    """
    Description:
        Function will display the grid and draw line charts of the closing value of
        Alphabet Inc. between October 3, 2016 to October 7, 2016.

    Parameter:
        None
      
    Return:
        None    
    """

    data_frame = pd.read_csv("new_fdata.csv", parse_dates=['Date'])

    plt.figure(figsize=(10, 6))
    plt.plot(data_frame['Date'], data_frame['Close'], marker='o', color='b', linestyle='-', label='Closing Value')

    plt.grid(linestyle='-', linewidth=0.5, color='blue')

    plt.title('Closing Value of Alphabet Inc. (Oct 3, 2016 - Oct 7, 2016)')
    plt.xlabel('Date')
    plt.ylabel('Closing Value')

    plt.legend()

    plt.tight_layout()
    plt.show()


def main():
    try:
        plot_chart_with_grid()


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 14. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn
# off ticks.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to display the grid and draw line charts of the closing value of
        Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
        rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn
        off ticks.

'''


def plot_chart_with_grid():

    """
    Description:
        Function will display the grid and draw line charts of the closing value of
        Alphabet Inc. between October 3, 2016 to October 7, 2016. will turn on grid but turn off ticks

    Parameter:
        None
      
    Return:
        None    
    """

    data_frame = pd.read_csv("new_fdata.csv", parse_dates=['Date'])

    plt.figure(figsize=(10, 6))
    plt.plot(data_frame['Date'], data_frame['Close'], marker='o', color='b', linestyle='-', label='Closing Value')

    plt.grid(which='both', linestyle='-', linewidth=0.5, color='blue')  # Major grid
    plt.minorticks_on()  # Enable minor ticks
    plt.grid(which='minor', linestyle='-.', linewidth=0.5, color='cyan')  # Minor grid

    # Turn off ticks
    plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False)

    plt.title('Closing Value of Alphabet Inc. (Oct 3, 2016 - Oct 7, 2016)')
    plt.xlabel('Date')
    plt.ylabel('Closing Value')

    plt.legend()

    plt.tight_layout()
    plt.show()


def main():
    try:
        plot_chart_with_grid()


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()

# %% [markdown]
# 15. Write a Python program to create multiple plots.

# %%
'''

@Author:Naveen Madev Naik
@Date: 2024-08-09
@Last Modified by: Naveen Madev Naik
@Last Modified time: 2024-08-09
@Title :Python program to create multiple plots.

'''


def multiple_plot():

    """
    Description:
        Function will create multiple plots.

    Parameter:
        None
      
    Return:
        None    
    """

    x = np.linspace(0, 2 * np.pi, 100)  # X values from 0 to 2π
    y_sin = np.sin(x)  # Sine values
    y_cos = np.cos(x)  # Cosine values
    y_tan = np.tan(x)  # Tangent values

    # Create a figure
    plt.figure(figsize=(10, 15))

    # Sine Plot (Top subplot)
    plt.subplot(3, 1, 1)
    plt.plot(x, y_sin, color='r', linestyle='-', marker='o', label='Sine')
    plt.title('Sine Function')
    plt.xlabel('X Axis')
    plt.ylabel('sin(x)')
    plt.legend()
    plt.grid(True)

    # Cosine Plot (Middle subplot)
    plt.subplot(3, 1, 2)
    plt.plot(x, y_cos, color='b', linestyle='--', marker='x', label='Cosine')
    plt.title('Cosine Function')
    plt.xlabel('X Axis')
    plt.ylabel('cos(x)')
    plt.legend()
    plt.grid(True)

    # Tangent Plot (Bottom subplot)
    plt.subplot(3, 1, 3)
    plt.plot(x, y_tan, color='g', linestyle='-.', marker='s', label='Tangent')
    plt.title('Tangent Function')
    plt.xlabel('X Axis')
    plt.ylabel('tan(x)')
    plt.ylim(-10, 10)  # Limit y-axis to avoid extreme values
    plt.legend()
    plt.grid(True)

    # Adjust layout
    plt.tight_layout()

    # Show the plots
    plt.show()


def main():
    try:
        multiple_plot()


    except ValueError as e:
        print(f"Invalid input -->{e}")    

if __name__=="__main__":
    main()
